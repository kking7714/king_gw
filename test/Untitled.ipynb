# %%
import pandas as pd
import numpy as np
import random
import requests as req
import json
#West River ID 8575923
#Baltimore: 8574680

# %%
api_call = req.get('https://tidesandcurrents.noaa.gov/api/datagetter?date=today&station=8574680&product=water_level&units=english&time_zone=lst&application=Tides_and_Currents&datum=STND&format=json')

# %%
api_call.json()
# Out:
# {'data': [{'f': '1,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:00',
#    'v': '6.007'},
#   {'f': '0,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:06',
#    'v': '5.984'},
#   {'f': '0,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:12',
#    'v': '5.974'},
#   {'f': '1,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:18',
#    'v': '5.951'},
#   {'f': '1,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:24',
#    'v': '5.932'},
#   {'f': '0,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:30',
#    'v': '5.922'},
#   {'f': '1,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:36',
#    'v': '5.902'},
#   {'f': '1,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:42',
#    'v': '5.886'},
#   {'f': '0,0,0,0',
#    'q': 'p',
#    's': '0.003',
#    't': '2017-11-15 19:48',
#    'v': '5.873'},
#   {'f': '1,0,0,0',
#    'q': 'p',
# ...
